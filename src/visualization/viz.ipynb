# %%
import os, sys

currentdir = os.path.dirname(os.path.realpath("__file__"))
parentdir = os.path.dirname(
    os.path.dirname(os.path.dirname(os.path.realpath("__file__")))
)
sys.path.append(parentdir)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "../../data/interim/"
query = "user == '-N2FwY4uC3d7' and '2020-01-25' < date < '2020-01-29'"
acti = pd.read_csv(path + "actigraph_binned.csv").query(query)
call = pd.read_csv(path + "call_binned.csv").query(query)
sms = pd.read_csv(path + "sms_binned.csv").query(query)
screen = pd.read_csv(path + "screen_binned.csv").query(query)

# %%
# Merge the DataFrames on 'user' and 'date'
merged_df = acti.merge(
    call, on=["user", "date"], how="outer", suffixes=("_acti", "_call")
)
merged_df = merged_df.merge(
    sms, on=["user", "date"], how="outer", suffixes=("", "_sms")
)
merged_df = merged_df.merge(screen, on=["user", "date"], how="outer")

# %%
screen
# Out:
#            user        date  screen_off_durationtotal_00  \
# 1  -N2FwY4uC3d7  2020-01-26                     1041.859
# 2  -N2FwY4uC3d7  2020-01-27                        0.000
# 3  -N2FwY4uC3d7  2020-01-28                        0.042
#
#    screen_off_durationtotal_06  screen_off_durationtotal_12  \
# 1                     7503.153                    20057.239
# 2                     7366.852                    16472.479
# 3                     1907.894                    18868.026
#
#    screen_off_durationtotal_18  screen_on_durationtotal_00  \
# 1                    31936.866                      57.839
# 2                    19470.187                       0.000
# 3                    37788.343                    3846.083
#
#    screen_on_durationtotal_06  screen_on_durationtotal_12  \
# 1                    2945.000                  530.495000
# 2                     114.106                 1756.995999
# 3                    4272.468                 2587.868000
#
#    screen_on_durationtotal_18  screen_use_durationtotal_00  \
# 1                 4143.683999                       92.582
# 2                  550.710000                        0.000
# 3                  135.382000                        0.000
#
#    screen_use_durationtotal_06  screen_use_durationtotal_12  \
# 1                      160.075                   388.234000
# 2                      290.964                   433.091000
# 3                       72.641                   453.667999
#
#    screen_use_durationtotal_18
# 1                      444.831
# 2                      422.266
# 3                      297.118
