# %%
import pandas as pd
import seaborn as sns
import json

from sklearn.manifold import (
    MDS,
    TSNE,
    Isomap,
    LocallyLinearEmbedding,
    SpectralEmbedding,
)
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px

# %% [markdown]
# # CORONA

# %%
freq = "4epochs"
study = "corona"
with open(f"../config/features.txt") as f:
    features = json.load(f)

FEATURES = features[study][freq]
OVERIDDEN_FEATURES = [
    "heart_rate_variability_avg",
    "stepsx1000:total",
    "steps:night",
    "steps:morning",
    "steps:afternoon",
    "steps:evening",
    "tst",
    "midsleep",
]
id_cols = ["subject_id", "date", "dayofweek"]
raw_behavior_vector = pd.read_csv(
    f"/m/cs/work/luongn1/digirhythm/data/processed/corona/vector_corona_{freq}.csv",
    index_col=0,
)

raw_behavior_vector.dropna(subset=FEATURES, inplace=True)
raw_behavior_vector["date"] = pd.to_datetime(raw_behavior_vector["date"])
raw_behavior_vector["dayofweek"] = raw_behavior_vector["date"].apply(
    lambda x: "weekday" if x.weekday() < 5 else "weekend"
)

behavior_vector = raw_behavior_vector[FEATURES + id_cols]
behavior_vector = (
    behavior_vector.groupby(["subject_id", "dayofweek"])
    .median(numeric_only=True)
    .reset_index()
)
behavior_vector
# Out:
#      subject_id dayofweek  heart_rate_variability_avg:norm  \
# 0      38758730   weekday                         0.373333
# 1      38758730   weekend                         0.373333
# 2      49285282   weekday                         0.338710
# 3      49285282   weekend                         0.354839
# 4      91109228   weekday                         0.590909
# ..          ...       ...                              ...
# 235  4240001906   weekend                         0.411111
# 236  4270145196   weekday                         0.348837
# 237  4270145196   weekend                         0.343023
# 238  4278070280   weekday                         0.339623
# 239  4278070280   weekend                         0.339623
#
#      stepsx1000:total:norm  steps:night:norm  steps:morning:norm  \
# 0                 0.199636          0.000446            0.294043
# 1                 0.173831          0.025180            0.117370
# 2                 0.453290          0.009685            0.211143
# 3                 0.491622          0.010343            0.166263
# 4                 0.235751          0.001836            0.129324
# ..                     ...               ...                 ...
# 235               0.276647          0.014883            0.138808
# 236               0.399854          0.001538            0.388754
# 237               0.355025          0.002306            0.271806
# 238               0.313261          0.006162            0.372292
# 239               0.412524          0.003660            0.232069
#
#      steps:afternoon:norm  steps:evening:norm  tst:norm  midsleep:norm
# 0                0.354501            0.342915  0.543171       0.411515
# 1                0.435532            0.311570  0.505495       0.526667
# 2                0.488594            0.203783  0.415584       0.735032
# 3                0.517223            0.279662  0.635065       0.751618
# 4                0.313134            0.446722  0.599681       0.253373
# ..                    ...                 ...       ...            ...
# 235              0.436880            0.304388  0.353612       0.630456
# 236              0.381071            0.208058  0.495690       0.171533
# 237              0.578787            0.108429  0.618534       0.291058
# 238              0.319953            0.314604  0.437037       0.430124
# 239              0.308657            0.308779  0.514815       0.570652
#
# [240 rows x 10 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
behavior_vector_pca = pca.fit_transform(behavior_vector[FEATURES])

# %%
import plotly.express as px

fig = px.scatter(
    x=behavior_vector_pca[:, 0],
    y=behavior_vector_pca[:, 1],
    color=behavior_vector["dayofweek"],
)
fig.update_layout(
    title="PCA visualization",
    xaxis_title="First component",
    yaxis_title="Second component",
)
fig.show()

# %%
tsne = TSNE(
    n_components=2,
    n_iter=500,
    n_iter_without_progress=150,
    n_jobs=2,
    random_state=0,
)


behavior_vector_tsne = tsne.fit_transform(behavior_vector[FEATURES])

fig = px.scatter(
    x=behavior_vector_tsne[:, 0],
    y=behavior_vector_tsne[:, 1],
    color=behavior_vector["dayofweek"],
)
fig.update_layout(
    title="t-SNE visualization",
    xaxis_title="First t-SNE component",
    yaxis_title="Second t-SNE component",
)
fig.show()

# %% [markdown]
# # MOMO

# %%
freq = "4epochs"
study = "momo"
with open(f"../config/features.txt") as f:
    features = json.load(f)


FEATURES = features[study][freq]
id_cols = ["user", "device", "group", "date", "dayofweek"]
raw_behavior_vector = pd.read_csv(
    f"/m/cs/work/luongn1/digirhythm/data/processed/momo/vector_momo_{freq}.csv",
    index_col=0,
)

raw_behavior_vector.dropna(subset=FEATURES, inplace=True)
raw_behavior_vector["date"] = pd.to_datetime(raw_behavior_vector["date"])
raw_behavior_vector["dayofweek"] = raw_behavior_vector["date"].apply(
    lambda x: "weekday" if x.weekday() < 5 else "weekend"
)

# %%
raw_behavior_vector[FEATURES]
# Out:
#        location:n_sps:norm  location:entropy:norm  location:log_variance:norm  \
# 650                    1.0               0.698555                    0.302449
# 651                    0.5               0.000000                    0.663186
# 652                    0.5               0.000000                    0.582221
# 653                    0.5               0.000000                    0.517813
# 655                    0.5               0.000000                    0.372991
# ...                    ...                    ...                         ...
# 23079                  0.5               0.000000                    0.097003
# 23080                  0.5               0.000000                    0.139960
# 23081                  0.5               0.000000                    0.118377
# 23082                  0.5               0.000000                    0.099360
# 23120                  0.5               0.000000                    0.166146
#
#        location:proportion_home  application:count:comm:night:norm  \
# 650                    0.410959                           0.000000
# 651                    0.032787                           0.096774
# 652                    0.280000                           0.000000
# 653                    0.125000                           0.000000
# 655                    0.276596                           0.000000
# ...                         ...                                ...
# 23079                  0.470588                           0.000000
# 23080                  0.328767                           0.000000
# 23081                  0.234375                           0.090909
# 23082                  0.428571                           1.000000
# 23120                  0.226415                           0.000000
#
#        application:count:comm:morning:norm  \
# 650                               0.311111
# 651                               0.096774
# 652                               0.390244
# 653                               0.114754
# 655                               0.333333
# ...                                    ...
# 23079                             0.166667
# 23080                             0.024390
# 23081                             0.000000
# 23082                             0.000000
# 23120                             0.000000
#
#        application:count:comm:afternoon:norm  \
# 650                                 0.200000
# 651                                 0.645161
# 652                                 0.536585
# 653                                 0.426230
# 655                                 0.458333
# ...                                      ...
# 23079                               0.666667
# 23080                               0.024390
# 23081                               0.272727
# 23082                               0.000000
# 23120                               1.000000
#
#        application:count:comm:evening:norm  \
# 650                               0.488889
# 651                               0.161290
# 652                               0.073171
# 653                               0.459016
# 655                               0.208333
# ...                                    ...
# 23079                             0.166667
# 23080                             0.951220
# 23081                             0.636364
# 23082                             0.000000
# 23120                             0.000000
#
#        application:duration:comm:total:norm
# 650                                0.000000
# 651                                1.000000
# 652                                0.017273
# 653                                0.218250
# 655                                0.063519
# ...                                     ...
# 23079                              0.006885
# 23080                              0.219037
# 23081                              0.049695
# 23082                              0.050137
# 23120                              0.002720
#
# [7122 rows x 9 columns]

# %%
tsne = TSNE(
    n_components=2,
    n_iter=500,
    n_iter_without_progress=150,
    n_jobs=2,
    random_state=0,
)

behavior_vector_tsne = tsne.fit_transform(
    behavior_vector[
        [
            "location:n_sps:norm",
            "location:entropy:norm",
            "location:log_variance:norm",
            "location:proportion_home",
            "screen:screen_use_durationtotal:sum:norm",
        ]
    ]
)


fig = px.scatter(
    x=behavior_vector_tsne[:, 2],
    y=behavior_vector_tsne[:, 0],
    color=behavior_vector["dayofweek"],
)
fig.update_layout(
    title="t-SNE visualization",
    xaxis_title="First t-SNE",
    yaxis_title="Second t-SNE",
)
fig.show()

# %%
import pandas as pd

# Check missing data
fp = "/m/cs/work/luongn1/digirhythm/data/interim/momo/location_4epochs.csv"
loc_df = pd.read_csv(fp, index_col=0)

loc_df.dropna(subset=["location:n_bins"])
# Out:
#              date        device          user  location:dist_total  \
# index
# 0      2020-03-05  1YfNysXDlFgA  _swxQrt999Wh            71.781959
# 1      2020-03-06  1YfNysXDlFgA  _swxQrt999Wh         28648.370691
# 2      2020-03-07  1YfNysXDlFgA  _swxQrt999Wh         61571.901456
# 3      2020-03-08  1YfNysXDlFgA  _swxQrt999Wh         36131.548273
# 4      2020-03-09  1YfNysXDlFgA  _swxQrt999Wh         29043.869031
# ...           ...           ...           ...                  ...
# 4363   2021-12-31  zL2u8PjLTiEp  JRmdtSaUsFUc         21629.340298
# 4364   2022-01-01  zL2u8PjLTiEp  JRmdtSaUsFUc          2822.835820
# 4365   2022-01-02  zL2u8PjLTiEp  JRmdtSaUsFUc          1916.094612
# 4366   2022-01-03  zL2u8PjLTiEp  JRmdtSaUsFUc          2670.823648
# 4367   2022-01-04  zL2u8PjLTiEp  JRmdtSaUsFUc          8152.715664
#
#        location:n_bins  location:speed_average  location:speed_variance  \
# index
# 0                 35.0                0.094921                 0.081324
# 1                 33.0                1.658357                11.305301
# 2                 94.0                3.308958                50.263543
# 3                102.0                1.664093                15.883845
# 4                 39.0                1.234567                 6.738450
# ...                ...                     ...                      ...
# 4363              86.0                1.434593                 5.131924
# 4364              84.0                1.139881                 1.670515
# 4365              68.0                1.035735                 0.773663
# 4366              86.0                0.989477                 2.435862
# 4367              83.0                1.030663                 2.542813
#
#        location:speed_max  location:variance  location:log_variance  ...  \
# index                                                                ...
# 0                1.346408       2.283467e-09             -19.897571  ...
# 1               13.619089       3.841770e-03              -5.561822  ...
# 2               26.685600       2.970338e-02              -3.516494  ...
# 3               21.779348       9.015095e-03              -4.708855  ...
# 4               10.709632       3.879500e-03              -5.552049  ...
# ...                   ...                ...                    ...  ...
# 4363            13.150000       5.752862e-04              -7.460643  ...
# 4364             7.900000       1.560505e-07             -15.673086  ...
# 4365             4.290000       1.008176e-07             -16.109953  ...
# 4366            13.160000       1.095102e-07             -16.027248  ...
# 4367            12.150000       2.809735e-04              -8.177250  ...
#
#        location:n_transitions  location:n_top1  location:n_top2  \
# index
# 0                         0.0             31.0              0.0
# 1                         2.0             13.0              5.0
# 2                         2.0             16.0              7.0
# 3                         1.0             16.0              3.0
# 4                         2.0             19.0              3.0
# ...                       ...              ...              ...
# 4363                      2.0             13.0              4.0
# 4364                      0.0             12.0              0.0
# 4365                      0.0             17.0              0.0
# 4366                      0.0             15.0              0.0
# 4367                      4.0             12.0              9.0
#
#        location:n_top3  location:n_top4  location:n_top5  location:entropy  \
# index
# 0                  0.0              0.0              0.0          0.000000
# 1                  0.0              0.0              0.0          0.000000
# 2                  1.0              0.0              0.0          2.772589
# 3                  0.0              0.0              0.0          0.000000
# 4                  0.0              0.0              0.0          0.000000
# ...                ...              ...              ...               ...
# 4363               0.0              0.0              0.0          0.000000
# 4364               0.0              0.0              0.0          0.000000
# 4365               0.0              0.0              0.0          0.000000
# 4366               0.0              0.0              0.0          0.000000
# 4367               2.0              0.0              0.0          2.484907
#
#        location:normalized_entropy        group  date.1
# index
# 0                         0.000000      mmm-bpd       0
# 1                         0.000000      mmm-bpd       1
# 2                         4.000000      mmm-bpd       2
# 3                         0.000000      mmm-bpd       3
# 4                         0.000000      mmm-bpd       4
# ...                            ...          ...     ...
# 4363                      0.000000  mmm-control    4363
# 4364                      0.000000  mmm-control    4364
# 4365                      0.000000  mmm-control    4365
# 4366                      0.000000  mmm-control    4366
# 4367                      3.584963  mmm-control    4367
#
# [15200 rows x 26 columns]

# %%
#!pip install missingno
import missingno as msno
import seaborn as sns

msno.bar(loc_df)

# %%
uindex = loc_df.copy().set_index("user")
# msno.matrix(uindex)
uindex
# Out:
#                     date        device  location:dist_total  location:n_bins  \
# user
# _swxQrt999Wh  2020-03-05  1YfNysXDlFgA            71.781959             35.0
# _swxQrt999Wh  2020-03-06  1YfNysXDlFgA         28648.370691             33.0
# _swxQrt999Wh  2020-03-07  1YfNysXDlFgA         61571.901456             94.0
# _swxQrt999Wh  2020-03-08  1YfNysXDlFgA         36131.548273            102.0
# _swxQrt999Wh  2020-03-09  1YfNysXDlFgA         29043.869031             39.0
# ...                  ...           ...                  ...              ...
# JRmdtSaUsFUc  2021-12-31  zL2u8PjLTiEp         21629.340298             86.0
# JRmdtSaUsFUc  2022-01-01  zL2u8PjLTiEp          2822.835820             84.0
# JRmdtSaUsFUc  2022-01-02  zL2u8PjLTiEp          1916.094612             68.0
# JRmdtSaUsFUc  2022-01-03  zL2u8PjLTiEp          2670.823648             86.0
# JRmdtSaUsFUc  2022-01-04  zL2u8PjLTiEp          8152.715664             83.0
#
#               location:speed_average  location:speed_variance  \
# user
# _swxQrt999Wh                0.094921                 0.081324
# _swxQrt999Wh                1.658357                11.305301
# _swxQrt999Wh                3.308958                50.263543
# _swxQrt999Wh                1.664093                15.883845
# _swxQrt999Wh                1.234567                 6.738450
# ...                              ...                      ...
# JRmdtSaUsFUc                1.434593                 5.131924
# JRmdtSaUsFUc                1.139881                 1.670515
# JRmdtSaUsFUc                1.035735                 0.773663
# JRmdtSaUsFUc                0.989477                 2.435862
# JRmdtSaUsFUc                1.030663                 2.542813
#
#               location:speed_max  location:variance  location:log_variance  \
# user
# _swxQrt999Wh            1.346408       2.283467e-09             -19.897571
# _swxQrt999Wh           13.619089       3.841770e-03              -5.561822
# _swxQrt999Wh           26.685600       2.970338e-02              -3.516494
# _swxQrt999Wh           21.779348       9.015095e-03              -4.708855
# _swxQrt999Wh           10.709632       3.879500e-03              -5.552049
# ...                          ...                ...                    ...
# JRmdtSaUsFUc           13.150000       5.752862e-04              -7.460643
# JRmdtSaUsFUc            7.900000       1.560505e-07             -15.673086
# JRmdtSaUsFUc            4.290000       1.008176e-07             -16.109953
# JRmdtSaUsFUc           13.160000       1.095102e-07             -16.027248
# JRmdtSaUsFUc           12.150000       2.809735e-04              -8.177250
#
#               location:n_sps  ...  location:n_transitions  location:n_top1  \
# user                          ...
# _swxQrt999Wh             1.0  ...                     0.0             31.0
# _swxQrt999Wh             1.0  ...                     2.0             13.0
# _swxQrt999Wh             2.0  ...                     2.0             16.0
# _swxQrt999Wh             1.0  ...                     1.0             16.0
# _swxQrt999Wh             1.0  ...                     2.0             19.0
# ...                      ...  ...                     ...              ...
# JRmdtSaUsFUc             1.0  ...                     2.0             13.0
# JRmdtSaUsFUc             1.0  ...                     0.0             12.0
# JRmdtSaUsFUc             1.0  ...                     0.0             17.0
# JRmdtSaUsFUc             1.0  ...                     0.0             15.0
# JRmdtSaUsFUc             2.0  ...                     4.0             12.0
#
#               location:n_top2  location:n_top3  location:n_top4  \
# user
# _swxQrt999Wh              0.0              0.0              0.0
# _swxQrt999Wh              5.0              0.0              0.0
# _swxQrt999Wh              7.0              1.0              0.0
# _swxQrt999Wh              3.0              0.0              0.0
# _swxQrt999Wh              3.0              0.0              0.0
# ...                       ...              ...              ...
# JRmdtSaUsFUc              4.0              0.0              0.0
# JRmdtSaUsFUc              0.0              0.0              0.0
# JRmdtSaUsFUc              0.0              0.0              0.0
# JRmdtSaUsFUc              0.0              0.0              0.0
# JRmdtSaUsFUc              9.0              2.0              0.0
#
#               location:n_top5  location:entropy  location:normalized_entropy  \
# user
# _swxQrt999Wh              0.0          0.000000                     0.000000
# _swxQrt999Wh              0.0          0.000000                     0.000000
# _swxQrt999Wh              0.0          2.772589                     4.000000
# _swxQrt999Wh              0.0          0.000000                     0.000000
# _swxQrt999Wh              0.0          0.000000                     0.000000
# ...                       ...               ...                          ...
# JRmdtSaUsFUc              0.0          0.000000                     0.000000
# JRmdtSaUsFUc              0.0          0.000000                     0.000000
# JRmdtSaUsFUc              0.0          0.000000                     0.000000
# JRmdtSaUsFUc              0.0          0.000000                     0.000000
# JRmdtSaUsFUc              0.0          2.484907                     3.584963
#
#                     group  date.1
# user
# _swxQrt999Wh      mmm-bpd       0
# _swxQrt999Wh      mmm-bpd       1
# _swxQrt999Wh      mmm-bpd       2
# _swxQrt999Wh      mmm-bpd       3
# _swxQrt999Wh      mmm-bpd       4
# ...                   ...     ...
# JRmdtSaUsFUc  mmm-control    4363
# JRmdtSaUsFUc  mmm-control    4364
# JRmdtSaUsFUc  mmm-control    4365
# JRmdtSaUsFUc  mmm-control    4366
# JRmdtSaUsFUc  mmm-control    4367
#
# [20235 rows x 25 columns]

# %%
# Calculate the proportion of missing data by 'user' and 'group'
missing_proportion = (
    loc_df.groupby(["user", "group"])
    .apply(lambda x: x.isnull().mean())["location:dist_total"]
    .sort_values(ascending=False)
    .reset_index()
)

# Adjust display options
pd.set_option("display.max_rows", 50)  # Adjust as needed
sns.barplot(y=missing_proportion["location:dist_total"], x=missing_proportion.user)
missing_proportion
# Out:
#              user        group  location:dist_total
# 0    _swxQrt999Wh      mmm-bpd             0.946612
# 1    IZr3eFPWcYod  mmm-control             0.928375
# 2    vC2-2ajT7-1L      mmm-mdd             0.923077
# 3    U5cKPUTMu0fs      mmm-mdd             0.914286
# 4    RazDc_79nWZc      mmm-mdd             0.908257
# ..            ...          ...                  ...
# 114  G96iHU6Pr69i  mmm-control             0.000000
# 115  lzCmb_dbsPmO  mmm-control             0.000000
# 116  EsgBr1bwAc8a      mmm-mdd             0.000000
# 117  QvjcDKzUYGbN  mmm-control             0.000000
# 118  zVn4Ri3rADQI       mmm-bd             0.000000
#
# [119 rows x 3 columns]

# %%
missing_proportion[missing_proportion["location:dist_total"] > 0.2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /share/apps/anaconda-ci/fgci-centos7-generic/software/anaconda/2020-03-tf1/f43b17a3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location:dist_total'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-136583bafc7e> in <module>
# ----> 1 missing_proportion[missing_proportion["location:dist_total"] > 0.2]
#
# /share/apps/anaconda-ci/fgci-centos7-generic/software/anaconda/2020-03-tf1/f43b17a3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /share/apps/anaconda-ci/fgci-centos7-generic/software/anaconda/2020-03-tf1/f43b17a3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location:dist_total'

# %%
import sys

sys.path.append("../")
from config import PATHS
import niimpy
import pandas as pd

loc_df = niimpy.read_sqlite(
    PATHS["mmm-control"]["location"], table="awarelocation", tz="Europe/Helsinki"
)

# %%
sample = loc_df[
    loc_df.user.isin(["OP_J184Pjo-u", "o67VPudEvTUh", "5DWiLmu6c6u7"])
].reset_index()
sample["timestamp"] = sample["time"].astype(int)
sample["timestamp"] = sample["timestamp"] * 1000
sample.rename(columns={"device": "device_id"}, inplace=True)

sample.to_csv("locations.csv", index=False, quotechar='"')

# %%
rapids_loc_df = pd.read_csv("all_sensor_features.csv", index_col=0).reset_index()
missing_proportion_rapid = (
    rapids_loc_df.groupby(["pid"])
    .apply(lambda x: x.isnull().mean())["phone_locations_doryab_timeathome"]
    .sort_values(ascending=False)
    .reset_index()
)

missing_proportion_rapid
# Out:
#             pid  phone_locations_doryab_timeathome
# 0  o67VPudEvTUh                           0.876147
# 1  IZr3eFPWcYod                           0.857143
# 2  OP_J184Pjo-u                           0.083333
# 3  5DWiLmu6c6u7                           0.015748

# %%
missing_proportion = (
    loc_df.groupby(["user", "group", "device"])
    .apply(lambda x: x.isnull().mean())["location:n_home"]
    .sort_values(ascending=False)
    .reset_index()
)

missing_proportion
# Out:
#            user        group        device  location:n_home
# 0  OP_J184Pjo-u  mmm-control  S08mmOEJ6FaK         0.991525
# 1  IZr3eFPWcYod  mmm-control  s6KkdJEABQZR         0.944904
# 2  o67VPudEvTUh  mmm-control  rdHOrfJCBB0q         0.924419
# 3  5DWiLmu6c6u7  mmm-control  VnPdoH5luUXu         0.635294

# %%
# loc_df[loc_df.device.isin(rapids_loc_df.pid.unique())]
rapids_loc_df.pid.unique()
# Out:
# array(['IZr3eFPWcYod', '5DWiLmu6c6u7', 'o67VPudEvTUh', 'OP_J184Pjo-u'],
#       dtype=object)

# %%
#################
##PERSONALITY#####
##################

import pandas as pd
import statsmodels.api as sm

freq = "4epochs"
sim_baseline = pd.read_csv(
    f"/m/cs/work/luongn1/digirhythm/data/processed/corona/similarity_matrix/si/similarity_baseline_{freq}.csv",
    index_col=0,
)
survey = pd.read_csv(
    f"/m/cs/work/luongn1/digirhythm/data/interim/corona/survey_all.csv"
)
survey = survey[survey.gender != "non-binary"]
survey.gender = survey.gender.astype(int)

avg_sim_baseline = sim_baseline.mean(axis=1).to_frame(name="baseline_similarity")

df = (
    avg_sim_baseline.merge(
        survey, left_on=avg_sim_baseline.index, right_on="subject_id", how="left"
    )
    .groupby("subject_id")[
        [
            "baseline_similarity",
            "age",
            "occupation",
            "gender",
            "occupation",
            "MEQ",
            "BIG5_Neuroticism",
            "BIG5_Extraversion",
            "BIG5_Openness",
            "BIG5_Agreeableness",
            "BIG5_Conscientiousness",
        ]
    ]
    .mean()
    .reset_index()
)
df.dropna(inplace=True)

# Define independent variables (adding a constant for the intercept)
X = sm.add_constant(
    df[["baseline_similarity", "age", "occupation", "gender", "occupation", "MEQ"]]
)

# Dictionary to hold regression results for easy retrieval
results = {}

# Perform regression for each Big Five personality trait and store the results
for trait in [
    "BIG5_Neuroticism",
    "BIG5_Extraversion",
    "BIG5_Openness",
    "BIG5_Agreeableness",
    "BIG5_Conscientiousness",
]:
    y = df[trait]
    model = sm.OLS(y, X).fit()
    results[trait] = model.summary()

# Example to print the summary for 'BIG5_Neuroticism'
results
# Out:
# {'BIG5_Neuroticism': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:       BIG5_Neuroticism   R-squared:                       0.073
#  Model:                            OLS   Adj. R-squared:                  0.030
#  Method:                 Least Squares   F-statistic:                     1.713
#  Date:                Tue, 16 Apr 2024   Prob (F-statistic):              0.138
#  Time:                        23:28:41   Log-Likelihood:                -291.66
#  No. Observations:                 115   AIC:                             595.3
#  Df Residuals:                     109   BIC:                             611.8
#  Df Model:                           5
#  Covariance Type:            nonrobust
#  =======================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                   7.5978      7.376      1.030      0.305      -7.020      22.216
#  baseline_similarity     1.5876     10.820      0.147      0.884     -19.858      23.033
#  age                    -0.0336      0.020     -1.719      0.088      -0.072       0.005
#  occupation              0.0226      0.158      0.143      0.886      -0.290       0.336
#  occupation              0.0226      0.158      0.143      0.886      -0.290       0.336
#  gender                  1.4257      0.648      2.201      0.030       0.142       2.710
#  occupation              0.0226      0.158      0.143      0.886      -0.290       0.336
#  occupation              0.0226      0.158      0.143      0.886      -0.290       0.336
#  MEQ                     0.0561      0.224      0.250      0.803      -0.388       0.500
#  ==============================================================================
#  Omnibus:                       12.734   Durbin-Watson:                   2.069
#  Prob(Omnibus):                  0.002   Jarque-Bera (JB):                5.744
#  Skew:                           0.315   Prob(JB):                       0.0566
#  Kurtosis:                       2.104   Cond. No.                     3.03e+34
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.08e-64. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """,
#  'BIG5_Extraversion': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:      BIG5_Extraversion   R-squared:                       0.020
#  Model:                            OLS   Adj. R-squared:                 -0.025
#  Method:                 Least Squares   F-statistic:                    0.4484
#  Date:                Tue, 16 Apr 2024   Prob (F-statistic):              0.814
#  Time:                        23:28:41   Log-Likelihood:                -278.41
#  No. Observations:                 115   AIC:                             568.8
#  Df Residuals:                     109   BIC:                             585.3
#  Df Model:                           5
#  Covariance Type:            nonrobust
#  =======================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                  11.9715      6.573      1.821      0.071      -1.055      24.998
#  baseline_similarity    -3.0724      9.642     -0.319      0.751     -22.183      16.038
#  age                     0.0097      0.017      0.555      0.580      -0.025       0.044
#  occupation             -0.1674      0.141     -1.189      0.237      -0.446       0.112
#  occupation             -0.1674      0.141     -1.189      0.237      -0.446       0.112
#  gender                 -0.1117      0.577     -0.194      0.847      -1.256       1.032
#  occupation             -0.1674      0.141     -1.189      0.237      -0.446       0.112
#  occupation             -0.1674      0.141     -1.189      0.237      -0.446       0.112
#  MEQ                    -0.1311      0.199     -0.657      0.512      -0.526       0.264
#  ==============================================================================
#  Omnibus:                        4.393   Durbin-Watson:                   2.336
#  Prob(Omnibus):                  0.111   Jarque-Bera (JB):                2.506
#  Skew:                          -0.110   Prob(JB):                        0.286
#  Kurtosis:                       2.311   Cond. No.                     3.03e+34
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.08e-64. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """,
#  'BIG5_Openness': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:          BIG5_Openness   R-squared:                       0.047
#  Model:                            OLS   Adj. R-squared:                  0.003
#  Method:                 Least Squares   F-statistic:                     1.069
#  Date:                Tue, 16 Apr 2024   Prob (F-statistic):              0.381
#  Time:                        23:28:41   Log-Likelihood:                -249.26
#  No. Observations:                 115   AIC:                             510.5
#  Df Residuals:                     109   BIC:                             527.0
#  Df Model:                           5
#  Covariance Type:            nonrobust
#  =======================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                   7.9559      5.101      1.560      0.122      -2.155      18.066
#  baseline_similarity     6.4298      7.484      0.859      0.392      -8.403      21.262
#  age                     0.0050      0.014      0.367      0.714      -0.022       0.032
#  occupation             -0.1244      0.109     -1.138      0.258      -0.341       0.092
#  occupation             -0.1244      0.109     -1.138      0.258      -0.341       0.092
#  gender                 -0.2877      0.448     -0.642      0.522      -1.176       0.600
#  occupation             -0.1244      0.109     -1.138      0.258      -0.341       0.092
#  occupation             -0.1244      0.109     -1.138      0.258      -0.341       0.092
#  MEQ                    -0.2610      0.155     -1.686      0.095      -0.568       0.046
#  ==============================================================================
#  Omnibus:                        1.835   Durbin-Watson:                   2.154
#  Prob(Omnibus):                  0.399   Jarque-Bera (JB):                1.881
#  Skew:                          -0.288   Prob(JB):                        0.390
#  Kurtosis:                       2.751   Cond. No.                     3.03e+34
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.08e-64. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """,
#  'BIG5_Agreeableness': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:     BIG5_Agreeableness   R-squared:                       0.070
#  Model:                            OLS   Adj. R-squared:                  0.027
#  Method:                 Least Squares   F-statistic:                     1.637
#  Date:                Tue, 16 Apr 2024   Prob (F-statistic):              0.156
#  Time:                        23:28:41   Log-Likelihood:                -253.80
#  No. Observations:                 115   AIC:                             519.6
#  Df Residuals:                     109   BIC:                             536.1
#  Df Model:                           5
#  Covariance Type:            nonrobust
#  =======================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                  15.2852      5.307      2.880      0.005       4.768      25.803
#  baseline_similarity    -6.3452      7.785     -0.815      0.417     -21.775       9.084
#  age                     0.0114      0.014      0.809      0.420      -0.017       0.039
#  occupation             -0.1199      0.114     -1.054      0.294      -0.345       0.105
#  occupation             -0.1199      0.114     -1.054      0.294      -0.345       0.105
#  gender                  0.9567      0.466      2.053      0.043       0.033       1.880
#  occupation             -0.1199      0.114     -1.054      0.294      -0.345       0.105
#  occupation             -0.1199      0.114     -1.054      0.294      -0.345       0.105
#  MEQ                     0.0151      0.161      0.094      0.925      -0.304       0.334
#  ==============================================================================
#  Omnibus:                        5.238   Durbin-Watson:                   2.314
#  Prob(Omnibus):                  0.073   Jarque-Bera (JB):                5.325
#  Skew:                          -0.518   Prob(JB):                       0.0698
#  Kurtosis:                       2.806   Cond. No.                     3.03e+34
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.08e-64. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """,
#  'BIG5_Conscientiousness': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                OLS Regression Results
#  ==================================================================================
#  Dep. Variable:     BIG5_Conscientiousness   R-squared:                       0.051
#  Model:                                OLS   Adj. R-squared:                  0.008
#  Method:                     Least Squares   F-statistic:                     1.179
#  Date:                    Tue, 16 Apr 2024   Prob (F-statistic):              0.324
#  Time:                            23:28:41   Log-Likelihood:                -264.65
#  No. Observations:                     115   AIC:                             541.3
#  Df Residuals:                         109   BIC:                             557.8
#  Df Model:                               5
#  Covariance Type:                nonrobust
#  =======================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
#  ---------------------------------------------------------------------------------------
#  const                   8.9433      5.832      1.534      0.128      -2.615      20.502
#  baseline_similarity     1.2554      8.556      0.147      0.884     -15.701      18.212
#  age                     0.0089      0.015      0.572      0.569      -0.022       0.040
#  occupation             -0.0532      0.125     -0.425      0.671      -0.301       0.194
#  occupation             -0.0532      0.125     -0.425      0.671      -0.301       0.194
#  gender                  0.8089      0.512      1.579      0.117      -0.206       1.824
#  occupation             -0.0532      0.125     -0.425      0.671      -0.301       0.194
#  occupation             -0.0532      0.125     -0.425      0.671      -0.301       0.194
#  MEQ                     0.2416      0.177      1.365      0.175      -0.109       0.592
#  ==============================================================================
#  Omnibus:                        5.162   Durbin-Watson:                   1.826
#  Prob(Omnibus):                  0.076   Jarque-Bera (JB):                4.597
#  Skew:                          -0.411   Prob(JB):                        0.100
#  Kurtosis:                       2.466   Cond. No.                     3.03e+34
#  ==============================================================================
#
#  Warnings:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.08e-64. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """}

# %%
import scipy

for trait in [
    "BIG5_Neuroticism",
    "BIG5_Extraversion",
    "BIG5_Openness",
    "BIG5_Agreeableness",
    "BIG5_Conscientiousness",
]:
    print(scipy.stats.pearsonr(df[trait], df["baseline_similarity"]))
# Out:
# (-0.0008420580856612486, 0.9928738522788272)
# (-0.020245396839423016, 0.8299560418808951)
# (0.10855770233820725, 0.24815156742203856)
# (-0.06152036013628444, 0.5136632426913961)
# (0.0047473595658113765, 0.9598403844169919)
